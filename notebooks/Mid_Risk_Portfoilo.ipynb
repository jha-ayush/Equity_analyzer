# %%
# Import modules
import yfinance as yf 
import pandas as pd
import hvplot.pandas
import numpy as np
from pathlib import Path
from datetime import date 
import streamlit as st
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import plotly.graph_objects as go 
from pandas.tseries.offsets import DateOffset
from sklearn.preprocessing import StandardScaler
from sklearn import svm
from sklearn.metrics import classification_report




ticker = "AAL"
data = yf.download(ticker, start='2016-01-01', end='2022-12-31')
AAL_df = pd.DataFrame(data)
AAL_df.rename(columns={'Open': 'Open', 'High': 'High', 'Low': 'Low', 'Close': 'Close', 'Volume': 'Volume'}, inplace=True)
AAL_df = AAL_df.loc[:, ['Open', 'High', 'Low', 'Close', 'Volume']]
AAL_df = AAL_df.sort_index()
AAL_df.head()

ticker = "AMZN"
data = yf.download(ticker, start='2016-01-01', end='2022-12-31')
AMZN_df = pd.DataFrame(data)
AMZN_df.rename(columns={'Open': 'Open', 'High': 'High', 'Low': 'Low', 'Close': 'Close', 'Volume': 'Volume'}, inplace=True)
AMZN_df = AMZN_df.loc[:, ['Open', 'High', 'Low', 'Close', 'Volume']]
AMZN_df = AMZN_df.sort_index()
AMZN_df.head()

ticker = "GOOGL"
data = yf.download(ticker, start='2016-01-01', end='2022-12-31')
GOOGL_df = pd.DataFrame(data)
GOOGL_df.rename(columns={'Open': 'Open', 'High': 'High', 'Low': 'Low', 'Close': 'Close', 'Volume': 'Volume'}, inplace=True)
GOOGL_df = GOOGL_df.loc[:, ['Open', 'High', 'Low', 'Close', 'Volume']]
GOOGL_df = GOOGL_df.sort_index()
GOOGL_df.head()

ticker = "ADBE"
data = yf.download(ticker, start='2016-01-01', end='2022-12-31')
ADBE_df = pd.DataFrame(data)
ADBE_df.rename(columns={'Open': 'Open', 'High': 'High', 'Low': 'Low', 'Close': 'Close', 'Volume': 'Volume'}, inplace=True)
ADBE_df = ADBE_df.loc[:, ['Open', 'High', 'Low', 'Close', 'Volume']]
ADBE_df = ADBE_df.sort_index()
ADBE_df.head()

ticker = "ABT"
data = yf.download(ticker, start='2016-01-01', end='2022-12-31')
ABT_df = pd.DataFrame(data)
ABT_df.rename(columns={'Open': 'Open', 'High': 'High', 'Low': 'Low', 'Close': 'Close', 'Volume': 'Volume'}, inplace=True)
ABT_df = ABT_df.loc[:, ['Open', 'High', 'Low', 'Close', 'Volume']]
ABTL_df = ABT_df.sort_index()
ABT_df.head()






tickers = ["AAL", "AMZN", "GOOGL", "ADBE", "ABT"]
dataframes = []

for ticker in tickers:
    data = yf.download(ticker, start='2016-01-01', end='2022-12-31')
    df = pd.DataFrame(data)
    df.rename(columns={'Open': 'Open', 'High': 'High', 'Low': 'Low', 'Close': 'Close', 'Volume': 'Volume'}, inplace=True)
    df = df.loc[:, ['Open', 'High', 'Low', 'Close', 'Volume']]
    df = df.sort_index()
    dataframes.append(df)

final_df = pd.concat(dataframes)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
# Calculate the daily returns using the closing prices and the pct_change function
final_df["actual_returns"] = final_df["Close"].pct_change()

# Display sample data
final_df.head()
# Out:
#                  Open       High        Low      Close    Volume  \
# Date
# 2016-01-04  41.290001  41.349998  40.299999  40.910000  12037200
# 2016-01-05  41.180000  41.490002  39.950001  40.520000  10514200
# 2016-01-06  40.049999  41.700001  40.000000  41.230000  12393800
# 2016-01-07  40.970001  41.520000  39.680000  40.450001  11312900
# 2016-01-08  40.939999  41.360001  40.259998  40.369999   8853100
#
#             actual_returns
# Date
# 2016-01-04             NaN
# 2016-01-05       -0.009533
# 2016-01-06        0.017522
# 2016-01-07       -0.018918
# 2016-01-08       -0.001978

# %%
# Drop all NaN values from the DataFrame
final_df = final_df.dropna()

# Review the DataFrame
display(final_df.head())
display(final_df.tail())
# Out:
#                  Open       High        Low      Close    Volume  \
# Date
# 2016-01-05  41.180000  41.490002  39.950001  40.520000  10514200
# 2016-01-06  40.049999  41.700001  40.000000  41.230000  12393800
# 2016-01-07  40.970001  41.520000  39.680000  40.450001  11312900
# 2016-01-08  40.939999  41.360001  40.259998  40.369999   8853100
# 2016-01-11  40.560001  41.200001  39.900002  41.080002  15877500
#
#             actual_returns
# Date
# 2016-01-05       -0.009533
# 2016-01-06        0.017522
# 2016-01-07       -0.018918
# 2016-01-08       -0.001978
# 2016-01-11        0.017587
#                   Open        High         Low       Close   Volume  \
# Date
# 2022-12-23  107.669998  108.400002  107.099998  108.180000  2618400
# 2022-12-27  108.349998  109.050003  107.379997  108.570000  2927400
# 2022-12-28  109.019997  110.099998  107.739998  107.830002  3265200
# 2022-12-29  108.750000  110.760002  108.459999  110.309998  3047800
# ...

# %%
# Define a window size of 4
short_window = 4

# Create an SMA that uses short_window, and assign it to a new column named “sma_fast”
final_df.loc[:, 'sma_fast'] = final_df['Close'].rolling(window=short_window).mean()


# Define a window size of 100
long_window = 100

# Create an SMA that uses long_window, and assign it to a new column named “sma_slow”
final_df.loc[:, 'sma_slow'] = final_df['Close'].rolling(window=long_window).mean()


# Drop the NaNs using dropna()
final_df = final_df.dropna()




# Assign a copy of the `sma_fast` and `sma_slow` columns to a new DataFrame called `X`
X = final_df[['sma_fast', 'sma_slow']].shift().dropna().copy()

# Display sample data
display(X.head())
display(X.tail())
display(X.info())
# Out:
#              sma_fast  sma_slow
# Date
# 2016-05-27  31.890000   38.5022
# 2016-05-31  31.870000   38.4135
# 2016-06-01  31.809999   38.3203
# 2016-06-02  31.755000   38.2353
# 2016-06-03  31.795000   38.1483
#               sma_fast  sma_slow
# Date
# 2022-12-23  107.312498  104.0517
# 2022-12-27  107.709999  104.0374
# 2022-12-28  108.230000  104.0259
# 2022-12-29  108.152500  104.0117
# 2022-12-30  108.722500  104.0248
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8709 entries, 2016-05-27 to 2022-12-30
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sma_fast  8709 non-null   float64
#  1   sma_slow  8709 non-null   float64
# dtypes: float64(2)
# memory usage: 204.1 KB
# None

# %%
# Define a window size of 4
short_window = 4

# Create an SMA that uses short_window, and assign it to a new column named “sma_fast”
final_df.loc[:, 'sma_fast'] = final_df['Close'].rolling(window=short_window).mean()

# Define a window size of 100
long_window = 100

# Create an SMA that uses long_window, and assign it to a new column named “sma_slow”
final_df.loc[:, 'sma_slow'] = final_df['Close'].rolling(window=long_window).mean()


# Drop the NaNs using dropna()
final_df = final_df.dropna()

# Assign a copy of the `sma_fast` and `sma_slow` columns to a new DataFrame called `X`
X = final_df[['sma_fast', 'sma_slow']].shift().dropna().copy()

# Display sample data
display(X.head())
display(X.tail())
display(X.index.nunique())
# Out:
#              sma_fast  sma_slow
# Date
# 2016-10-18  38.462502   34.3924
# 2016-10-19  38.955001   34.4708
# 2016-10-20  39.302501   34.5606
# 2016-10-21  39.787500   34.6474
# 2016-10-24  40.117500   34.7269
#               sma_fast  sma_slow
# Date
# 2022-12-23  107.312498  104.0517
# 2022-12-27  107.709999  104.0374
# 2022-12-28  108.230000  104.0259
# 2022-12-29  108.152500  104.0117
# 2022-12-30  108.722500  104.0248
# 1762

# %%
X = X.loc[~X.index.duplicated(keep='first')]
X.head()
# Out:
#              sma_fast  sma_slow
# Date
# 2016-10-18  38.462502   34.3924
# 2016-10-19  38.955001   34.4708
# 2016-10-20  39.302501   34.5606
# 2016-10-21  39.787500   34.6474
# 2016-10-24  40.117500   34.7269

# %%
# Create a new column in the `trading_df` called "signal" setting its value to zero.
final_df.loc[:, 'signal'] = 0.0

# Create the signal to buy
final_df.loc[(final_df['actual_returns'] >= 0), 'signal'] = 1

# Create the signal to sell
final_df.loc[(final_df['actual_returns'] < 0), 'signal'] = -1

# Copy the new "signal" column to a new Series called `y`.
y = final_df['signal'].copy()


# Select the start of the training period

training_begin = X.loc['2021-01-01':'2021-01-31']

# Display the training begin date
print(training_begin)

# Select the ending period for the training data with an offset of 3 months
training_end = X.index.min() + DateOffset(months=9)

# Display the training end date
print(training_end)
# Out:
#             sma_fast  sma_slow
# Date
# 2021-01-04   15.9600   13.5328
# 2021-01-05   15.7275   13.5468
# 2021-01-06   15.6200   13.5657
# 2021-01-07   15.4625   13.5879
# 2021-01-08   15.3650   13.6084
# 2021-01-11   15.3650   13.6335
# 2021-01-12   15.2575   13.6575
# 2021-01-13   15.2225   13.6845
# 2021-01-14   15.2600   13.7148
# 2021-01-15   15.5875   13.7576
# 2021-01-19   15.7775   13.7808
# 2021-01-20   15.9250   13.8091
# 2021-01-21   16.0850   13.8429
# 2021-01-22   15.9325   13.8684
# 2021-01-25   15.9475   13.8907
# 2021-01-26   15.8125   13.9145
# 2021-01-27   15.6525   13.9388
# 2021-01-28   15.8350   13.9721
# 2021-01-29   16.4050   14.0195
# 2016-10-04 00:00:00
# /Users/kevster95/opt/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py:16: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.

# %%
# Generate the X_train and y_train DataFrames
# X_train = X.loc[training_begin]
X_train = X.loc['2021-01-01':'2021-12-31']
# y_train = y.loc[training_begin]
y_train = y.loc['2021-01-01':'2021-12-31']


# Display sample data
X_train.head()
# Out:
# /Users/kevster95/opt/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/kevster95/opt/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   """
#             sma_fast  sma_slow
# Date
# 2021-01-04   15.9600   13.5328
# 2021-01-05   15.7275   13.5468
# 2021-01-06   15.6200   13.5657
# 2021-01-07   15.4625   13.5879
# 2021-01-08   15.3650   13.6084

# %%
# Generate the X_train and y_train DataFrames
# X_train = X.loc[training_begin]
X_train = X.loc['2021-01-01':'2021-12-31']
# y_train = y.loc[training_begin]
y_train = y.loc['2021-01-01':'2021-12-31']

# Generate the X_test and y_test DataFrames
X_test = X.loc['2021-01-01':'2021-12-31']
y_test = y.loc['2021-01-01':'2021-12-31']

# Select the start of the training period
start_date = pd.to_datetime('2021-01-01')
end_date = pd.to_datetime('2021-12-31')

# Generate the X_train and y_train DataFrames
X_train = X.loc[(X.index >= start_date) & (X.index <= end_date)]
y_train = y.loc[(y.index >= start_date) & (y.index <= end_date)]

# Generate the X_test and y_test DataFrames
X_test = X.loc[(X.index >= start_date) & (X.index <= end_date)]
y_test = y.loc[(y.index >= start_date) & (y.index <= end_date)]



# Display sample data
X_test.head()
# Out:
# /Users/kevster95/opt/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/kevster95/opt/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   """
# /Users/kevster95/opt/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#
# ...

# %%
# Filter the date index and close columns
signals_df = final_df.loc[:,["Close"]]

# Set the short window and long windows
short_window = 50
long_window = 100

# Generate the short and long moving averages (50 and 100 days, respectively)
signals_df['SMA50'] = signals_df['Close'].rolling(window=short_window).mean()
signals_df['SMA100'] = signals_df['Close'].rolling(window=long_window).mean()
signals_df['Signal'] = 0.0

# Generate the trading signal 0 or 1,
# where 1 is the short-window (SMA50) greater than the long-window (SMA100)
# and 0 is when the condition is not met
signals_df['Signal'][short_window:] = np.where(
    signals_df['SMA50'][short_window:] > signals_df['SMA100'][short_window:], 1.0, 0.0
)

# Calculate the points in time when the Signal value changes
# Identify trade entry (1) and exit (-1) points
signals_df['Entry/Exit'] = signals_df['Signal'].diff()

# Review the DataFrame
signals_df.tail(10)
# Out:
#                  Close     SMA50    SMA100  Signal  Entry/Exit
# Date
# 2022-12-16  106.910004  102.8190  104.1328     0.0         0.0
# 2022-12-19  106.589996  102.9150  104.0951     0.0         0.0
# 2022-12-20  106.489998  103.0222  104.0716     0.0         0.0
# 2022-12-21  108.139999  103.1500  104.0578     0.0         0.0
# 2022-12-22  108.029999  103.3090  104.0517     0.0         0.0
# 2022-12-23  108.180000  103.4232  104.0374     0.0         0.0
# 2022-12-27  108.570000  103.5764  104.0259     0.0         0.0
# 2022-12-28  107.830002  103.6626  104.0117     0.0         0.0
# 2022-12-29  110.309998  103.7692  104.0248     0.0         0.0
# 2022-12-30  109.790001  104.0028  104.0436     0.0         0.0

# %%
# Visualize exit position relative to close price
exit = signals_df[signals_df['Entry/Exit'] == -1.0]['Close'].hvplot.scatter(
    color='yellow',
    marker='v',
    size=200,
    legend=False,
    ylabel='Price in $',
    width=1000,
    height=400
)

# Visualize entry position relative to close price
entry = signals_df[signals_df['Entry/Exit'] == 1.0]['Close'].hvplot.scatter(
    color='purple',
    marker='^',
    size=200,
    legend=False,
    ylabel='Price in $',
    width=1000,
    height=400
)

# Visualize close price for the investment
security_close = signals_df[['Close']].hvplot(
    line_color='lightgray',
    ylabel='Price in $',
    width=1000,
    height=400
)

# Visualize moving averages
moving_avgs = signals_df[['SMA50', 'SMA100']].hvplot(
    ylabel='Price in $',
    width=1000,
    height=400
)

# Create the overlay plot
entry_exit_plot = security_close * moving_avgs * entry * exit

# Show the plot
entry_exit_plot.opts(
    title="Low Risk Portfolio- SMA50, SMA100, Entry and Exit Points",
    width=1000,
    height=800
)
# Out:
# :Overlay
#    .Curve.I          :Curve   [Date]   (Close)
#    .NdOverlay.I      :NdOverlay   [Variable]
#       :Curve   [Date]   (value)
#    .Scatter.Close.I  :Scatter   [Date]   (Close)
#    .Scatter.Close.II :Scatter   [Date]   (Close)
